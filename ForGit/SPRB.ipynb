# %%
import numpy as np
import math
import pandas as pd 
import scipy.stats as stats 
import matplotlib.pyplot as plt
from numba.typed import List
import itertools
from scipy.stats import linregress
from numba import njit
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
from itertools import product

# %%
def give_all_comb(len):
    return [seq  for i, seq in enumerate(product([-1, 1], repeat=len))]

# %%
@njit
def seq_to_index(context):
    idx = 0
    for i in range(len(context)):
        idx = idx * 2 + (context[i] == 1)
    return idx

@njit
def homm_get_next_w(context_arr, memorySeq,memoryStrengthPlus, memoryStrengthMinus, order,gamma):
    act_pos = 0.0
    act_neg = 0.0
    
    lag_weights = np.exp(-gamma * (order - 1 - np.arange(order)))
    for i in range(len(memorySeq)):
        memory   = memorySeq[i]
        abs_dif  =  lag_weights*np.abs(memory - context_arr)
        sim      = np.exp(-np.sum(abs_dif))
        strengthPlus = memoryStrengthPlus[i]
        strengthMinus = memoryStrengthMinus[i]

        act_pos += strengthPlus * sim
        act_neg += strengthMinus * sim  # negative -1 evidence → positive +1 evidence

    total = act_pos + act_neg
    if total > 0.0:
        return act_pos / total
    return 0.5

@njit
def homm_add_to_memory(context_arr,resp, confidence, memoryStrengthPlus, memoryStrengthMinus, decay):
    idx = seq_to_index(context_arr)
    memoryStrengthPlus *= decay
    memoryStrengthMinus *= decay

    if resp ==1:
        memoryStrengthPlus[idx] += confidence
    else:
        memoryStrengthMinus[idx] += confidence

@njit
def build_context(resp_arr, i, k):
    context = np.zeros(k, dtype=np.int64)
    start = max(i - k, 0)
    length = i - start
    for j in range(length):
        context[k - length + j] = resp_arr[start + j]
    return context

def normalize_weights(weights, k_w):

    weights = np.asarray(weights, dtype=float)
    target_sum = 2 ** (k_w - 1)
    weights = target_sum * weights / np.sum(weights)

    for _ in range(100):
        excess = np.maximum(0, weights - 1)
        if np.sum(excess) < 1e-12:
            break                                   # all weights in [0, 1]
        weights = np.minimum(weights, 1)            # clip
        good = weights < 1
        if not np.any(good):
            break                                   # no room to redistribute
        weights[good] += np.sum(excess) / np.sum(good)

    return weights

# %%
import numpy as np
from numba import njit
from scipy.stats import norm as _norm

# Pre-computed 5-point Gauss-Legendre nodes and weights on [-1, 1]
_GL5_NODES   = np.array([-0.9061798459386640, -0.5384693101056831,
                           0.0,
                           0.5384693101056831,  0.9061798459386640])
_GL5_WEIGHTS = np.array([ 0.2369268850561891,  0.4786286704993665,
                           0.5688888888888889,
                           0.4786286704993665,  0.2369268850561891])

@njit
def _norm_pdf(x):
    return np.exp(-0.5 * x * x) / np.sqrt(2.0 * np.pi)

@njit
def _ddm_pdf_lower_core(t, v, a, w, sv, max_J=50, eps=1e-12):
    """
    Core lower-boundary PDF for a single (v, a, w) triple.
    σ is assumed = 1 here; caller must pre-scale v, a, sv by 1/σ.
    sv = inter-trial drift SD  (set 0 for no drift variability).
    w  = relative starting point in (0,1).
    """
    if t <= 0.0:
        return 1e-300
    if t < 1e-6:
        t = 1e-6

    one_plus = 1.0 + sv * sv * t
    denom = np.sqrt(t**3 * one_plus)

    expo = np.exp(
        (-(v * v) * t - 2.0 * v * a * w + (sv * sv) * (a * w) * (a * w))
        / (2.0 * one_plus)
    )

    sqrt_t = np.sqrt(t)
    s = 0.0
    prev_term = 0.0

    for j in range(max_J):
        if j % 2 == 0:
            rj = j * a + a * w
        else:
            rj = j * a + a * (1.0 - w)

        term = ((-1) ** j) * rj * _norm_pdf(rj / sqrt_t)
        s += term

        if j > 3 and np.abs(term) < eps and np.abs(prev_term) < eps:
            break
        prev_term = term

    pdf = (expo / denom) * s
    return max(pdf, 1e-300)


@njit
def ddm_pdf_lower_boundary(t, v, a, w, t0,
                            sv=0.0, sz=0.0, sigma=1.0,
                            max_J=50, eps=1e-12):
    """
    Lower-boundary PDF with:
      σ   (sigma)  – diffusion coefficient  [scales v, a, sv]
      sv           – inter-trial drift SD
      sz           – uniform starting-point range  w ~ Uniform(w-sz/2, w+sz/2)
                     integrated via 5-point Gauss-Legendre quadrature

    Reference for σ scaling:
        Blurton et al. (2017), J. Math. Psych. 76, 7-12  (eq. 1 footnote)
    Reference for sz quadrature approach:
        Ratcliff & Tuerlinckx (2002), Psychon. Bull. Rev. 9, 438-481
        (HDDM and fddm both implement sz this way in practice)
    """
    t_eff = t - t0
    if t_eff <= 0.0:
        return 1e-300

    # -------------------------------------------------------
    # σ handling: pure rescaling (σ is a scale parameter)
    # v/σ, a/σ, sv/σ are the normalised parameters
    # -------------------------------------------------------
    if sigma != 1.0:
        v  = v  / sigma
        a  = a  / sigma
        sv = sv / sigma

    # -------------------------------------------------------
    # sz = 0 → no starting-point variability, fast path
    # -------------------------------------------------------
    if sz <= 1e-10:
        return _ddm_pdf_lower_core(t_eff, v, a, w, sv, max_J, eps)

    # -------------------------------------------------------
    # sz > 0: Gauss-Legendre quadrature over
    #   w' ∈ [w - sz/2, w + sz/2]  (clipped to (0,1))
    #
    # (1/sz) ∫_{w-sz/2}^{w+sz/2} f(t|w') dw'
    #  = (1/2) Σ_i weight_i * f(t | w + (sz/2)*node_i)
    # -------------------------------------------------------
    # Hard-coded 5-point GL nodes and weights (on [-1, 1])
    n0 = -0.9061798459386640;  wt0 = 0.2369268850561891
    n1 = -0.5384693101056831;  wt1 = 0.4786286704993665
    n2 =  0.0;                 wt2 = 0.5688888888888889
    n3 =  0.5384693101056831;  wt3 = 0.4786286704993665
    n4 =  0.9061798459386640;  wt4 = 0.2369268850561891

    half_sz = sz * 0.5
    acc = 0.0

    for (node, wt) in ((n0, wt0), (n1, wt1), (n2, wt2), (n3, wt3), (n4, wt4)):
        w_prime = w + half_sz * node

        # Clip to valid range – avoid boundary singularities
        if w_prime <= 0.0:
            w_prime = 1e-6
        elif w_prime >= 1.0:
            w_prime = 1.0 - 1e-6

        acc += wt * _ddm_pdf_lower_core(t_eff, v, a, w_prime, sv, max_J, eps)

    pdf = 0.5 * acc          # factor 1/2 from change-of-variables
    return max(pdf, 1e-300)


def complete_run(data, params,weights):
    vSlope,vPower,vBias,a,t0,w,k,weight_w,weight_v,lapse,strength_bias = params
    winf = 0.2
    k_w = k

    w_part_1 = np.asarray(weights)
    w_part_2 = np.ones_like(weights) - np.flip(weights)
    weigths_use = np.concatenate((w_part_1,w_part_2))



    memorySeq = np.asarray(give_all_comb(k))

    memoryStrengthPlus = np.asarray([p*strength_bias for p in weigths_use])
    memoryStrengthMinus = np.asarray([(1-p)*strength_bias for p in weigths_use])

    p_pos_pre = [homm_get_next_w(seq, memorySeq,memoryStrengthPlus, memoryStrengthMinus, k, 0.0) for seq in memorySeq]
    

    

    return complete_run_fast(
        data["coherence"].to_numpy(np.float64),
        data["stim"].to_numpy(np.int8),
        data["response"].to_numpy(np.int8),
        data["rt"].to_numpy(np.float64),
        memorySeq, memoryStrengthPlus,memoryStrengthMinus,p_pos_pre,
        vSlope,vPower,vBias,a, t0, w, k,
        weight_w, weight_v, lapse
    )
@njit
def _sigmoid(x):
    if x >= 0:
        return 1.0 / (1.0 + np.exp(-x))
    ex = np.exp(x)
    return ex / (1.0 + ex)


@njit
def conf_2dsd(v_signed, a, resp, tau, sigma=1.0):

    mean_tc = a + resp * v_signed * tau
    sd = sigma * math.sqrt(tau)
    z = mean_tc / sd
    return 0.5 * (1.0 + math.erf(z * 0.7071067811865476))

@njit
def complete_run_fast(coherence, stim, resp, rt,
                      memorySeq, memoryStrengthPlus,memoryStrengthMinus,p_pos_pre,
                      vSlope,vPower,vBias,a, t0, w, k,
                      weight_w, weight_v, lapse):
    n = len(stim)
    likelihood = 0.0


    for i in range(n):
        
        a_orig = a
        
        context = build_context(resp, i, k)
        
        gamma= 0.0
        p_pos = p_pos_pre[seq_to_index(context)]

        

        a_eff = a_orig
        
        #print(f"this is the first {context}")

        pred_correct_dir = p_pos if stim[i] == 1 else (1.0 - p_pos)
        w_logit = np.log(w / (1.0 - w))
        w_up = _sigmoid(w_logit + weight_w * (2*p_pos - 1))


        w_sz = 0.0 #np.sqrt((weight_v**2 * 4*p_pos*(1-p_pos)) * tau)

        

        v_base = vSlope*coherence[i]**vPower + weight_v*(2*pred_correct_dir - 1)
        
        v_signed = v_base if stim[i] == 1 else -v_base

        # Step 3: add directional bias AFTER sign
        # vBias > 0 always pushes toward stim==1 boundary
        v_biased = v_signed + vBias

        # Step 4: fold for response (DDM lower-boundary trick)
        if resp[i] == 1:   # chose right
            v_eff = v_biased
            w_eff = w_up 
        else:              # chose left
            v_eff = -v_biased
            w_eff = 1.0 - w_up
        


        p_ddm   =  ddm_pdf_lower_boundary(rt[i], -v_eff, a_eff, 1.0-w_eff, t0,sz = w_sz)
        p_lapse = 0.5 / (4.0 - 0.15)
        p = (1.0 - lapse)*p_ddm + lapse*p_lapse
        if p > 0:
            likelihood += math.log(p)


    return likelihood

# %%
import numpy as np
import cma

# ── Indices into the 13 non-weight params ──────────────────────────────────
DDM_IDX     = [0, 1, 2, 3, 4, 5, 8]   # vSlope, vPower, vBias, a, t0, w, lapse, d
MEMORY_IDX  = [6, 7, 9, 10]            # weight_w, weight_v, gamma, bias_strength, ptau

# Neutral unit-cube values for frozen memory params during stage 1
MEMORY_NEUTRAL = [0.0, 0.0, 0.0, 0.0]

def make_rescale(bl, bh, ls):
    safe_bl = np.where(ls, bl, 1.0)
    safe_bh = np.where(ls, bh, 1.0)
    def rescale(x_unit):
        x = np.asarray(x_unit)
        log_vals = safe_bl * (safe_bh / safe_bl) ** x
        lin_vals = bl + x * (bh - bl)
        return np.where(ls, log_vals, lin_vals)
    return rescale


def fit_ddm_stage(df_participant, rescale, bounds_low, bounds_high, n_w,
                  n_restarts=5, maxiter=400):
    """Stage 1: fit only DDM params with memory frozen to neutral values."""
    n_params     = len(bounds_low)
    n_non_weight = n_params - n_w

    def neg_log_lik_ddm(x_ddm_unit):
        x_full = np.zeros(n_params)
        x_full[DDM_IDX]           = x_ddm_unit[:len(DDM_IDX)]
        x_full[MEMORY_IDX]        = MEMORY_NEUTRAL
        x_full[n_non_weight:]     = 0.5
        params = rescale(np.clip(x_full, 0.0, 1.0))
        vSlope, vPower, vBias, a, t0, w, weight_w, weight_v, lapse, bias_strength = params[:10]
        weights = params[10:]
        full_params = (vSlope, vPower, vBias, a, t0, w, 1,
                       weight_w, weight_v, lapse, bias_strength)
        ll = -complete_run(df_participant, full_params, weights)
        return ll if np.isfinite(ll) else 1e10

    n_ddm      = len(DDM_IDX)
    best_val   = np.inf
    best_x_ddm = None

    for _ in range(n_restarts):
        x0     = np.random.uniform(0.0, 1.0, n_ddm)
        sigma0 = 0.3

        opts = cma.CMAOptions()
        opts['bounds']        = [[0.0]*n_ddm, [1.0]*n_ddm]
        opts['maxiter']       = maxiter
        opts['popsize']       = 15
        opts['tolstagnation'] = 30
        opts['tolfun']        = 1e-5
        opts['tolx']          = 1e-5
        opts['verbose']       = -9
        opts['seed']          = np.random.randint(0, 100000)

        try:
            es = cma.CMAEvolutionStrategy(x0, sigma0, opts)
            es.optimize(neg_log_lik_ddm)
            result = es.result
            if np.isfinite(result.fbest) and result.fbest < best_val:
                best_val   = result.fbest
                best_x_ddm = np.clip(result.xbest, 0.0, 1.0)
        except Exception:
            continue

    print(f"  Stage 1 DDM fit: LL = {-best_val:.2f}")
    return best_x_ddm


def fit_mle(df_participant, n_restarts=8, k_values=range(1, 6), fast=False):

    best_overall = {"params": None, "k": None, "neg_ll": np.inf, "aic": np.inf, "param_names": None}
    print(f"Running optimization for k = {list(k_values)}")

    # ── Stage 1: run ONCE, outside k-loop ─────────────────────────────────
    n_w_s1       = 1
    bounds_low_s1  = np.array([0.01, 0.01, -10.0, 0.1, 0.0, 0.3, 0.000001, 0.0000001, 0.0, 0.00001] + [0.0]*n_w_s1)
    bounds_high_s1 = np.array([20.0, 2.0,   10.0,  5.0, 0.5, 0.7, 100.0,   30.0,   1.0, 10000.0 ] + [1.0]*n_w_s1)
    log_scale_s1   = np.array([False, False, False, False, False, False, False, False, False, True] + [False]*n_w_s1)
    rescale_s1     = make_rescale(bounds_low_s1, bounds_high_s1, log_scale_s1)

    print("Running Stage 1 (DDM only)...")
    ddm_x_unit = fit_ddm_stage(df_participant, rescale_s1, bounds_low_s1, bounds_high_s1, n_w_s1)

    # ── Stage 2: k-loop with full fits ────────────────────────────────────
    for k in k_values:
        k_w = min(5, k) - 1
        n_w = 2**k_w

        bounds_low  = np.array([0.01, 0.01, -5.0, 0.1, 0.0, 0.3, 0.000001, 0.0000001, 0.0, 0.00001] + [0.0]*n_w)
        bounds_high = np.array([10.0, 1.0,   5.0,  5.0, 0.5, 0.7, 30.0,   30.0,   1.0, 10000.0 ] + [1.0]*n_w)
        log_scale   = np.array([False, False, False, False, False, False, False, True, False, True] + [False]*n_w)

        param_names = ["vSlope","vPower","vBias","a","t0","w","weight_w","weight_v",
                       "lapse","bias_strength"] + ["w" + str(i) for i in range(n_w)]
        n_params = len(bounds_low)

        print(f"\n=== Optimizing with fixed k = {k} (n_params={n_params}) ===")

        rescale = make_rescale(bounds_low, bounds_high, log_scale)

        def neg_log_lik(params_unit):
            params = rescale(np.clip(params_unit, 0.0, 1.0))
            vSlope, vPower, vBias, a, t0, w, weight_w, weight_v, lapse, bias_strength = params[:10]
            weights = params[10:]
            full_params = (vSlope, vPower, vBias, a, t0, w, k, weight_w, weight_v, lapse, bias_strength)
            ll = -complete_run(df_participant, full_params, weights)
            return ll if np.isfinite(ll) else 1e10

        best_k_params   = None
        best_k_val      = np.inf
        successful_fits = 0

        print("  Running Stage 2 (full fit)...")
        for i in range(n_restarts):
            x0 = np.random.uniform(0.0, 1.0, n_params)
            if i % 4 != 0 and ddm_x_unit is not None:
                x0[DDM_IDX]    = np.clip(ddm_x_unit + np.random.normal(0, 0.05, len(DDM_IDX)), 0.0, 1.0)
                x0[MEMORY_IDX] = np.random.uniform(0.0, 1.0, len(MEMORY_IDX))

            sigma0 = 0.3
            opts = cma.CMAOptions()
            opts['bounds']        = [[0.0]*n_params, [1.0]*n_params]
            opts['maxiter']       = 200 if fast else 700 + 100*k_w
            opts['popsize']       = 10  if fast else 10
            opts['tolstagnation'] = 15  if fast else 50 + 10*k_w
            opts['tolfun']        = 1e-3
            opts['tolx']          = 1e-3
            opts['verbose']       = -9
            opts['seed']          = np.random.randint(0, 100000)
            opts['CMA_stds']      = [1.0] * n_params

            try:
                es = cma.CMAEvolutionStrategy(x0, sigma0, opts)
                es.optimize(neg_log_lik)
                result = es.result
                if np.isfinite(result.fbest):
                    successful_fits += 1
                    if result.fbest < best_k_val:
                        best_k_val    = result.fbest
                        best_k_params = rescale(np.clip(result.xbest, 0.0, 1.0))
                        print(f"  Restart {i+1} ({'warm' if i%4!=0 else 'random'}): "
                              f"LL = {-best_k_val:.2f}  [{result.stop}]")
            except Exception as e:
                print(f"  Restart {i+1} failed: {e}")
                continue

        print(f"  Successful fits for k={k}: {successful_fits}/{n_restarts}")

        if best_k_params is not None:
            k_aic = 2 * n_params + 2 * best_k_val
            print(f"  AIC for k={k}: {k_aic:.2f}  (vs current best: {best_overall['aic']:.2f})")
            if k_aic < best_overall["aic"]:
                best_overall["neg_ll"]      = best_k_val
                best_overall["aic"]         = k_aic
                best_overall["params"]      = np.asarray(list(best_k_params) + [-1.0] * (2**4 - n_w))
                best_overall["k"]           = k
                best_overall["param_names"] = param_names

    if best_overall["params"] is not None:
        print("\n=== Best overall fit (by AIC) ===")
        print(f"k = {best_overall['k']}")
        for name, val in zip(best_overall["param_names"], best_overall["params"]):
            print(f"  {name}: {val:.4f}")
        print(f"Final Log-Likelihood : {-best_overall['neg_ll']:.2f}")
        print(f"Final AIC            : {best_overall['aic']:.2f}")
        return best_overall["params"], best_overall["k"], -best_overall["neg_ll"], best_overall["aic"]
    else:
        print("No successful fits found!")
        return None, None, None, None

# %%
def fit_all_participants(df_path, output_path=None, test_first_n=None):
    """Fit RDM to all participants"""
    
    # Load data
    df = pd.read_csv(df_path)
    df["orig_order"] = np.arange(len(df))

    df = (
        df.sort_values(["sj", "session", "orig_order"])
        .reset_index(drop=True)
    )



    print(f"Loaded data with {len(df)} rows")
    print(f"Unique participants: {df['sj'].nunique()}")
    print(f"Columns: {list(df.columns)}")
    
    # Check data structure
    print("\nData preview:")
    print(df.head())
    
    # Initialize results list
    results = []
    
    # Get participant list
    participants = df['sj'].unique()
    if test_first_n:
        participants = participants[:test_first_n]
        print(f"Testing first {test_first_n} participants only")

    
    # Loop over participants
    for i, participant_id in enumerate(participants):
        print(f"\n{'='*50}")
        print(f"Fitting participant {participant_id} ({i+1}/{len(participants)})")
        print(f"{'='*50}")
        
        participant_df = df[df['sj'] == participant_id]
        print(f"Participant has {len(participant_df)} trials")
        

        params,k, max_ll,aic = fit_mle(participant_df, n_restarts=7)  # Fewer restarts for testing
        
        if params is not None:
            results.append([participant_id] + list(params) + [k] + [max_ll] + [aic])
            print(f"✓ Success: LL = {max_ll:.2f}")
        else:
            results.append([participant_id] + [None] * 11 + [None])
            print("✗ Failed: No valid fit found")
                
    
    # Create results DataFrame
    columns = ["id","vSlope","vPower","vBias","a","t0","w","weight_w","weight_v","lapse","bias_strength"]+["w" + str(i) for i in range(2**4)]+["k", "max_log_lik","aic"]

    results_df = pd.DataFrame(results, columns=columns)

    print(f"\nParameter summary (successful fits only):")
    numeric_cols = columns

    print(results_df[numeric_cols].describe())
    
    # Save results
    if output_path:
        results_df.to_csv(output_path, index=False)
        print(f"\nResults saved to: {output_path}")
    
    return results_df

# Example usage:
if __name__ == "__main__":
    # Test with first few participants only
    results_df = fit_all_participants(
        df_path="../data_all_subjects.csv",
        output_path="SPRB.csv",
        test_first_n=25  # Test with first 3 participants only
    )
    
    print("\nFirst few results:")
    print(results_df)
# Out:
# Loaded data with 78201 rows
# Unique participants: 22
# Columns: ['Unnamed: 0', 'sj', 'condition', 'session', 'block', 'coherence', 'stim', 'response', 'rt', 'orig_order']
#
# Data preview:
#    Unnamed: 0   sj condition  session  block  coherence  stim  response  \
# 0           0  1.0   Neutral      1.0    1.0        0.6   1.0       1.0
# 1           1  1.0   Neutral      1.0    1.0        0.0   1.0      -1.0
# 2           2  1.0   Neutral      1.0    1.0        0.0   1.0      -1.0
# 3           3  1.0   Neutral      1.0    1.0        0.4  -1.0      -1.0
# 4           4  1.0   Neutral      1.0    1.0        0.4  -1.0      -1.0
#
#       rt  orig_order
# 0  0.319           0
# 1  0.433           1
# 2  0.500           2
# 3  0.267           3
# 4  0.317           4
# Testing first 25 participants only
#
# ==================================================
# Fitting participant 1.0 (1/22)
# ==================================================
# Participant has 3408 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 853.74
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 854.18  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 854.19  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 855.96  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 855.96  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1689.92  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 854.31  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 856.13  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1688.26  (vs current best: -1689.92)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 856.40  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1684.80  (vs current best: -1689.92)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 858.64  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1681.29  (vs current best: -1689.92)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 864.37  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1676.75  (vs current best: -1689.92)
#
# === Best overall fit (by AIC) ===
# k = 1
#   vSlope: 4.2914
#   vPower: 0.7040
#   vBias: 1.2724
#   a: 1.2040
#   t0: 0.0077
#   w: 0.4275
#   weight_w: 0.0000
#   weight_v: 0.2764
#   lapse: 0.0000
#   bias_strength: 0.6695
#   w0: 0.3140
# Final Log-Likelihood : 855.96
# Final AIC            : -1689.92
# ✓ Success: LL = 855.96
#
# ==================================================
# Fitting participant 2.0 (2/22)
# ==================================================
# Participant has 3598 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 1036.82
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1036.82  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1036.82  [{'tolfun': 0.001}]
#   Restart 3 (warm): LL = 1036.85  [{'tolfun': 0.001}]
#   Restart 5 (random): LL = 1036.87  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -2051.74  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1039.42  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 1050.01  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -2076.01  (vs current best: -2051.74)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1041.66  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1041.66  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1041.67  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -2055.33  (vs current best: -2076.01)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1036.81  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1054.17  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -2072.33  (vs current best: -2076.01)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1036.82  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1036.82  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1036.86  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 1037.14  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 1061.24  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -2070.48  (vs current best: -2076.01)
#
# === Best overall fit (by AIC) ===
# k = 2
#   vSlope: 4.4476
#   vPower: 0.4516
#   vBias: -0.2245
#   a: 1.1032
#   t0: 0.2140
#   w: 0.5406
#   weight_w: 0.0000
#   weight_v: 1.7021
#   lapse: 0.0252
#   bias_strength: 0.0223
#   w0: 0.5155
#   w1: 0.3966
# Final Log-Likelihood : 1050.01
# Final AIC            : -2076.01
# ✓ Success: LL = 1050.01
#
# ==================================================
# Fitting participant 3.0 (3/22)
# ==================================================
# Participant has 3600 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 761.70
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 774.95  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 774.95  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 775.04  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1528.07  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 798.04  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 798.04  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 800.25  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1576.49  (vs current best: -1528.07)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 776.11  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 798.49  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 800.75  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1573.51  (vs current best: -1576.49)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 806.21  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1576.43  (vs current best: -1576.49)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 808.74  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1565.48  (vs current best: -1576.49)
#
# === Best overall fit (by AIC) ===
# k = 2
#   vSlope: 6.2241
#   vPower: 0.6387
#   vBias: -0.7846
#   a: 1.1804
#   t0: 0.2614
#   w: 0.5324
#   weight_w: 0.0000
#   weight_v: 0.7852
#   lapse: 0.0411
#   bias_strength: 11.2580
#   w0: 0.6395
#   w1: 0.1415
# Final Log-Likelihood : 800.25
# Final AIC            : -1576.49
# ✓ Success: LL = 800.25
#
# ==================================================
# Fitting participant 4.0 (4/22)
# ==================================================
# Participant has 3424 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = -560.56
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -560.57  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -560.56  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -560.56  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -558.90  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = -558.89  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = -552.25  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: 1126.51  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -552.21  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: 1128.42  (vs current best: 1126.51)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -560.56  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -546.98  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -546.98  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: 1121.95  (vs current best: 1126.51)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -560.56  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -560.56  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -560.56  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -560.56  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = -554.09  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: 1144.18  (vs current best: 1121.95)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -560.53  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -548.20  [{'maxiter': 1100}]
#   Restart 7 (warm): LL = -544.03  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: 1140.06  (vs current best: 1121.95)
#
# === Best overall fit (by AIC) ===
# k = 3
#   vSlope: 4.0685
#   vPower: 0.4059
#   vBias: 0.0906
#   a: 1.6313
#   t0: 0.1488
#   w: 0.4949
#   weight_w: 0.0000
#   weight_v: 0.3664
#   lapse: 0.0203
#   bias_strength: 168.3401
#   w0: 0.4194
#   w1: 0.2500
#   w2: 0.7217
#   w3: 0.0075
# Final Log-Likelihood : -546.98
# Final AIC            : 1121.95
# ✓ Success: LL = -546.98
#
# ==================================================
# Fitting participant 5.0 (5/22)
# ==================================================
# Participant has 3595 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 2623.79
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2623.75  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2635.57  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 2635.57  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 2635.57  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -5249.15  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2623.79  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2678.53  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -5333.06  (vs current best: -5249.15)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2660.98  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2682.98  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 2710.43  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -5392.85  (vs current best: -5333.06)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2670.18  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 2670.20  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 2722.61  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 2722.61  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -5409.22  (vs current best: -5392.85)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2674.47  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2674.47  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 2739.78  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 2739.78  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -5427.56  (vs current best: -5409.22)
#
# === Best overall fit (by AIC) ===
# k = 5
#   vSlope: 6.1477
#   vPower: 0.5299
#   vBias: -0.4073
#   a: 0.9308
#   t0: 0.2357
#   w: 0.5601
#   weight_w: 0.0000
#   weight_v: 2.4529
#   lapse: 0.0229
#   bias_strength: 0.0011
#   w0: 0.2018
#   w1: 0.6800
#   w2: 0.5815
#   w3: 0.6512
#   w4: 0.2908
#   w5: 0.1898
#   w6: 0.4764
#   w7: 0.6085
#   w8: 0.5047
#   w9: 0.3460
#   w10: 0.9971
#   w11: 0.0633
#   w12: 0.6378
#   w13: 0.2002
#   w14: 0.4358
#   w15: 0.7030
# Final Log-Likelihood : 2739.78
# Final AIC            : -5427.56
# ✓ Success: LL = 2739.78
#
# ==================================================
# Fitting participant 6.0 (6/22)
# ==================================================
# Participant has 3487 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = -3157.67
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -3102.52  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = -3101.14  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: 6224.28  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -3157.67  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -3097.70  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -3094.50  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -3094.49  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: 6212.99  (vs current best: 6224.28)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -3093.79  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -3093.79  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = -3093.79  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: 6215.57  (vs current best: 6212.99)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -3093.58  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -3093.56  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -3089.45  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: 6214.90  (vs current best: 6212.99)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -3157.66  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -3086.97  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -3084.98  [{'maxiter': 1100}]
#   Restart 5 (random): LL = -3081.43  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = -3081.43  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: 6214.86  (vs current best: 6212.99)
#
# === Best overall fit (by AIC) ===
# k = 2
#   vSlope: 2.4759
#   vPower: 0.5248
#   vBias: -0.0926
#   a: 1.9163
#   t0: 0.3867
#   w: 0.5174
#   weight_w: 0.5325
#   weight_v: 0.2344
#   lapse: 0.0258
#   bias_strength: 0.0000
#   w0: 0.6194
#   w1: 0.2415
# Final Log-Likelihood : -3094.49
# Final AIC            : 6212.99
# ✓ Success: LL = -3094.49
#
# ==================================================
# Fitting participant 7.0 (7/22)
# ==================================================
# Participant has 3600 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 1120.92
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1123.63  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 1123.63  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1123.63  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 1123.63  [{'tolfun': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -2225.26  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1123.66  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1123.67  [{'tolfun': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -2223.34  (vs current best: -2225.26)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1129.49  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1129.50  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -2231.00  (vs current best: -2225.26)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1120.92  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1130.04  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -2224.08  (vs current best: -2231.00)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1133.86  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -2215.72  (vs current best: -2231.00)
#
# === Best overall fit (by AIC) ===
# k = 3
#   vSlope: 3.9699
#   vPower: 0.3284
#   vBias: 0.6455
#   a: 1.1811
#   t0: 0.3109
#   w: 0.4747
#   weight_w: 0.1809
#   weight_v: 0.0000
#   lapse: 0.0234
#   bias_strength: 0.0005
#   w0: 0.0085
#   w1: 0.5480
#   w2: 0.3157
#   w3: 0.2573
# Final Log-Likelihood : 1129.50
# Final AIC            : -2231.00
# ✓ Success: LL = 1129.50
#
# ==================================================
# Fitting participant 9.0 (8/22)
# ==================================================
# Participant has 3600 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 868.04
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 900.73  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 902.95  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 902.96  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 902.96  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 902.96  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1783.93  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 903.24  [{'tolfun': 0.001}]
#   Restart 4 (warm): LL = 903.24  [{'tolfun': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1782.48  (vs current best: -1783.93)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 908.00  [{'tolfun': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1788.00  (vs current best: -1783.93)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 909.54  [{'tolfun': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1783.08  (vs current best: -1788.00)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 868.03  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 913.44  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1774.87  (vs current best: -1788.00)
#
# === Best overall fit (by AIC) ===
# k = 3
#   vSlope: 3.6944
#   vPower: 0.2734
#   vBias: -0.1884
#   a: 1.3268
#   t0: 0.3992
#   w: 0.5391
#   weight_w: 0.3156
#   weight_v: 0.0000
#   lapse: 0.0140
#   bias_strength: 1.5539
#   w0: 0.8754
#   w1: 0.4170
#   w2: 0.9824
#   w3: 0.1654
# Final Log-Likelihood : 908.00
# Final AIC            : -1788.00
# ✓ Success: LL = 908.00
#
# ==================================================
# Fitting participant 11.0 (9/22)
# ==================================================
# Participant has 3476 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 231.66
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 254.06  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 290.96  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 290.96  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -559.91  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 254.44  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 254.45  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 254.54  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -485.09  (vs current best: -559.91)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 293.95  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -559.90  (vs current best: -559.91)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 231.66  [{'tolfun': 0.001}]
#   Restart 2 (warm): LL = 260.94  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 298.46  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -560.91  (vs current best: -559.91)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 300.86  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -549.73  (vs current best: -560.91)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 3.0021
#   vPower: 0.2717
#   vBias: -0.0243
#   a: 1.3163
#   t0: 0.3249
#   w: 0.5003
#   weight_w: 0.0000
#   weight_v: 1.1089
#   lapse: 0.0113
#   bias_strength: 0.0001
#   w0: 0.9907
#   w1: 0.2734
#   w2: 0.5322
#   w3: 0.3565
#   w4: 0.7398
#   w5: 0.2262
#   w6: 0.6510
#   w7: 0.3208
# Final Log-Likelihood : 298.46
# Final AIC            : -560.91
# ✓ Success: LL = 298.46
#
# ==================================================
# Fitting participant 12.0 (10/22)
# ==================================================
# Participant has 3594 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 739.41
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 741.31  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 741.31  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 741.31  [{'tolfun': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1460.63  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 744.59  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 744.59  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 744.63  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1465.26  (vs current best: -1460.63)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 742.21  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 747.44  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 795.77  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1563.54  (vs current best: -1465.26)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 739.41  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 814.77  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 814.77  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 814.77  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1593.53  (vs current best: -1563.54)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 828.11  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1604.22  (vs current best: -1593.53)
#
# === Best overall fit (by AIC) ===
# k = 5
#   vSlope: 5.0473
#   vPower: 0.4463
#   vBias: -0.1318
#   a: 1.4691
#   t0: 0.4388
#   w: 0.5084
#   weight_w: 0.0000
#   weight_v: 1.3245
#   lapse: 0.0175
#   bias_strength: 35.8730
#   w0: 0.1227
#   w1: 0.9326
#   w2: 0.4156
#   w3: 0.7915
#   w4: 0.5216
#   w5: 0.2097
#   w6: 0.5024
#   w7: 0.7648
#   w8: 0.5827
#   w9: 0.2585
#   w10: 0.9989
#   w11: 0.1312
#   w12: 0.4465
#   w13: 0.2819
#   w14: 0.5910
#   w15: 0.8889
# Final Log-Likelihood : 828.11
# Final AIC            : -1604.22
# ✓ Success: LL = 828.11
#
# ==================================================
# Fitting participant 13.0 (11/22)
# ==================================================
# Participant has 3587 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 213.51
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 220.39  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 220.39  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 220.39  [{'tolfun': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -418.78  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 224.03  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 224.04  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 234.43  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 234.43  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -444.86  (vs current best: -418.78)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 213.51  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 213.51  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 225.65  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 225.65  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -423.30  (vs current best: -444.86)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 213.51  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 256.64  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 256.65  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -477.29  (vs current best: -444.86)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 262.47  [{'maxiter': 1100}]
#   Restart 5 (random): LL = 262.65  [{'maxiter': 1100}]
#   Restart 6 (warm): LL = 262.70  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -473.40  (vs current best: -477.29)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 3.0750
#   vPower: 0.2984
#   vBias: -0.2582
#   a: 1.3388
#   t0: 0.1407
#   w: 0.4950
#   weight_w: 0.0000
#   weight_v: 0.9843
#   lapse: 0.0134
#   bias_strength: 0.1085
#   w0: 0.1756
#   w1: 0.6148
#   w2: 0.5978
#   w3: 0.7101
#   w4: 0.8374
#   w5: 0.0032
#   w6: 0.6848
#   w7: 0.4678
# Final Log-Likelihood : 256.65
# Final AIC            : -477.29
# ✓ Success: LL = 256.65
#
# ==================================================
# Fitting participant 14.0 (12/22)
# ==================================================
# Participant has 3565 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 663.37
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 667.93  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 667.94  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 669.02  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1316.04  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 668.25  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 669.85  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1315.71  (vs current best: -1316.04)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 663.36  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 671.82  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 671.82  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 675.93  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 675.93  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1323.87  (vs current best: -1316.04)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 678.07  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 678.07  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 678.07  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 678.07  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 678.07  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1320.15  (vs current best: -1323.87)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 686.50  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1321.01  (vs current best: -1323.87)
#
# === Best overall fit (by AIC) ===
# k = 3
#   vSlope: 4.4026
#   vPower: 0.5856
#   vBias: -1.0510
#   a: 1.2585
#   t0: 0.0688
#   w: 0.5918
#   weight_w: 0.0517
#   weight_v: 0.4332
#   lapse: 0.0114
#   bias_strength: 1208.5857
#   w0: 0.9998
#   w1: 0.2742
#   w2: 0.4602
#   w3: 0.6265
# Final Log-Likelihood : 675.93
# Final AIC            : -1323.87
# ✓ Success: LL = 675.93
#
# ==================================================
# Fitting participant 15.0 (13/22)
# ==================================================
# Participant has 3561 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 774.17
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 778.38  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 778.39  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 778.41  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -1534.82  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 774.17  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 782.42  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -1540.84  (vs current best: -1534.82)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 782.89  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 802.16  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -1576.31  (vs current best: -1540.84)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 783.60  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 809.12  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 809.13  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -1582.25  (vs current best: -1576.31)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 818.46  [{'maxiter': 1100}]
#   Restart 5 (random): LL = 818.47  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 818.48  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -1584.96  (vs current best: -1582.25)
#
# === Best overall fit (by AIC) ===
# k = 5
#   vSlope: 4.2460
#   vPower: 0.3069
#   vBias: -0.1647
#   a: 1.3762
#   t0: 0.1238
#   w: 0.4965
#   weight_w: 0.0000
#   weight_v: 1.1502
#   lapse: 0.0273
#   bias_strength: 0.0013
#   w0: 0.0016
#   w1: 0.8965
#   w2: 0.4015
#   w3: 0.6161
#   w4: 0.3532
#   w5: 0.1422
#   w6: 0.5420
#   w7: 0.9875
#   w8: 0.6798
#   w9: 0.4464
#   w10: 0.6733
#   w11: 0.4204
#   w12: 0.3026
#   w13: 0.5614
#   w14: 0.6222
#   w15: 0.6399
# Final Log-Likelihood : 818.48
# Final AIC            : -1584.96
# ✓ Success: LL = 818.48
#
# ==================================================
# Fitting participant 16.0 (14/22)
# ==================================================
# Participant has 3546 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 888.92
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1013.98  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1014.00  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -2005.99  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 927.71  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1018.88  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -2013.77  (vs current best: -2005.99)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 945.73  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1059.68  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 1059.68  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1059.68  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -2091.36  (vs current best: -2013.77)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 957.04  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1069.97  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -2103.94  (vs current best: -2091.36)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 962.46  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 962.47  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1078.65  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1078.65  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -2105.30  (vs current best: -2103.94)
#
# === Best overall fit (by AIC) ===
# k = 5
#   vSlope: 6.1531
#   vPower: 0.5318
#   vBias: -0.0955
#   a: 1.2220
#   t0: 0.1429
#   w: 0.5042
#   weight_w: 0.0000
#   weight_v: 2.1161
#   lapse: 0.0381
#   bias_strength: 0.0703
#   w0: 0.2800
#   w1: 0.6766
#   w2: 0.9504
#   w3: 0.4354
#   w4: 0.7072
#   w5: 0.1082
#   w6: 0.5952
#   w7: 0.4369
#   w8: 0.7532
#   w9: 0.3935
#   w10: 0.9272
#   w11: 0.1064
#   w12: 0.6977
#   w13: 0.2459
#   w14: 0.3764
#   w15: 0.3267
# Final Log-Likelihood : 1078.65
# Final AIC            : -2105.30
# ✓ Success: LL = 1078.65
#
# ==================================================
# Fitting participant 18.0 (15/22)
# ==================================================
# Participant has 3595 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = -1010.76
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -987.90  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -982.01  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: 1986.03  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -1010.76  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -1010.76  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -1010.76  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -987.36  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: 1998.73  (vs current best: 1986.03)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -980.92  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -980.92  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: 1989.83  (vs current best: 1986.03)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -1010.78  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -976.85  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = -976.85  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: 1989.70  (vs current best: 1986.03)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -979.93  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -973.82  [{'maxiter': 1100}]
#   Restart 6 (warm): LL = -973.79  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: 1999.58  (vs current best: 1986.03)
#
# === Best overall fit (by AIC) ===
# k = 1
#   vSlope: 6.1784
#   vPower: 0.7458
#   vBias: 0.1174
#   a: 1.5038
#   t0: 0.2206
#   w: 0.5222
#   weight_w: 0.2360
#   weight_v: 0.4709
#   lapse: 0.0523
#   bias_strength: 0.2483
#   w0: 0.6899
# Final Log-Likelihood : -982.01
# Final AIC            : 1986.03
# ✓ Success: LL = -982.01
#
# ==================================================
# Fitting participant 19.0 (16/22)
# ==================================================
# Participant has 3593 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 37.04
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 50.68  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 62.84  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -103.69  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 37.04  [{'tolfun': 0.001}]
#   Restart 2 (warm): LL = 68.43  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 68.43  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -112.86  (vs current best: -103.69)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 66.84  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 80.15  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -132.30  (vs current best: -112.86)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 74.23  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 86.66  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 86.66  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -137.31  (vs current best: -132.30)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 36.98  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 89.72  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -127.44  (vs current best: -137.31)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 4.2909
#   vPower: 0.5448
#   vBias: -0.0155
#   a: 1.3012
#   t0: 0.2451
#   w: 0.5069
#   weight_w: 0.2115
#   weight_v: 0.7079
#   lapse: 0.0156
#   bias_strength: 0.0000
#   w0: 0.0087
#   w1: 0.7454
#   w2: 0.4027
#   w3: 0.5590
#   w4: 0.5393
#   w5: 0.2777
#   w6: 0.2792
#   w7: 0.7470
# Final Log-Likelihood : 86.66
# Final AIC            : -137.31
# ✓ Success: LL = 86.66
#
# ==================================================
# Fitting participant 20.0 (17/22)
# ==================================================
# Participant has 3588 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 231.58
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 239.42  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 376.69  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 376.69  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -731.39  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 231.55  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 239.59  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 378.41  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 378.42  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = 378.42  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -732.85  (vs current best: -731.39)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 231.58  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 244.27  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 382.49  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -736.99  (vs current best: -732.85)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 388.61  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 388.61  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 388.61  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -741.22  (vs current best: -736.99)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 231.58  [{'tolfun': 0.001}]
#   Restart 2 (warm): LL = 398.40  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 398.40  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -744.80  (vs current best: -741.22)
#
# === Best overall fit (by AIC) ===
# k = 5
#   vSlope: 5.5265
#   vPower: 0.6411
#   vBias: 0.2774
#   a: 1.3361
#   t0: 0.2069
#   w: 0.4771
#   weight_w: 0.0000
#   weight_v: 1.4852
#   lapse: 0.0146
#   bias_strength: 0.0062
#   w0: 0.2195
#   w1: 0.8968
#   w2: 0.0021
#   w3: 0.8732
#   w4: 0.4213
#   w5: 0.6946
#   w6: 0.1940
#   w7: 0.7474
#   w8: 0.4887
#   w9: 0.8029
#   w10: 0.4964
#   w11: 0.5296
#   w12: 0.3771
#   w13: 0.3984
#   w14: 0.0906
#   w15: 0.9369
# Final Log-Likelihood : 398.40
# Final AIC            : -744.80
# ✓ Success: LL = 398.40
#
# ==================================================
# Fitting participant 21.0 (18/22)
# ==================================================
# Participant has 3560 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 1069.32
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1069.30  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1070.90  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1070.91  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 1070.91  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -2119.83  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1069.32  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1074.20  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1074.20  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -2124.41  (vs current best: -2119.83)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1069.32  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 1075.49  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1075.49  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -2122.97  (vs current best: -2124.41)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1078.52  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -2121.04  (vs current best: -2124.41)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1069.32  [{'tolfun': 0.001}]
#   Restart 3 (warm): LL = 1082.09  [{'maxiter': 1100}]
#   Restart 4 (warm): LL = 1082.09  [{'maxiter': 1100}]
#   Restart 5 (random): LL = 1086.89  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -2121.77  (vs current best: -2124.41)
#
# === Best overall fit (by AIC) ===
# k = 2
#   vSlope: 5.8743
#   vPower: 0.6973
#   vBias: -1.0630
#   a: 1.2339
#   t0: 0.0423
#   w: 0.5269
#   weight_w: 0.0000
#   weight_v: 0.2338
#   lapse: 0.0140
#   bias_strength: 6017.6368
#   w0: 0.0965
#   w1: 0.2757
# Final Log-Likelihood : 1074.20
# Final AIC            : -2124.41
# ✓ Success: LL = 1074.20
#
# ==================================================
# Fitting participant 23.0 (19/22)
# ==================================================
# Participant has 3522 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = -529.56
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -527.40  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = -527.40  [{'tolx': 0.001}]
#   Restart 5 (random): LL = -527.40  [{'tolfun': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: 1076.81  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -533.22  [{'tolfun': 0.001}]
#   Restart 2 (warm): LL = -527.03  [{'tolfun': 0.001}]
#   Restart 4 (warm): LL = -527.03  [{'tolfun': 0.001}]
#   Restart 6 (warm): LL = -527.03  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: 1078.05  (vs current best: 1076.81)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -524.65  [{'tolfun': 0.001}]
#   Restart 4 (warm): LL = -524.65  [{'tolx': 0.001}]
#   Restart 7 (warm): LL = -524.65  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: 1077.30  (vs current best: 1076.81)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -533.22  [{'tolfun': 0.001}]
#   Restart 2 (warm): LL = -522.76  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = -522.76  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = -522.76  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: 1081.52  (vs current best: 1076.81)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = -514.04  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: 1080.07  (vs current best: 1076.81)
#
# === Best overall fit (by AIC) ===
# k = 1
#   vSlope: 5.4001
#   vPower: 1.0000
#   vBias: 1.3087
#   a: 1.5606
#   t0: 0.1895
#   w: 0.4774
#   weight_w: 4.7324
#   weight_v: 0.0006
#   lapse: 0.0146
#   bias_strength: 0.0007
#   w0: 0.5103
# Final Log-Likelihood : -527.40
# Final AIC            : 1076.81
# ✓ Success: LL = -527.40
#
# ==================================================
# Fitting participant 24.0 (20/22)
# ==================================================
# Participant has 3520 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 171.50
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 173.16  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 173.19  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 181.32  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -340.64  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 185.18  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -346.37  (vs current best: -340.64)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 173.73  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 173.73  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 186.70  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -345.39  (vs current best: -346.37)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 171.50  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 197.50  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -359.00  (vs current best: -346.37)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 171.50  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 171.51  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 202.73  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -353.46  (vs current best: -359.00)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 3.5161
#   vPower: 0.3014
#   vBias: -0.1633
#   a: 1.5701
#   t0: 0.0197
#   w: 0.5176
#   weight_w: 0.0000
#   weight_v: 0.7938
#   lapse: 0.0043
#   bias_strength: 482.8928
#   w0: 0.5076
#   w1: 0.4305
#   w2: 0.3681
#   w3: 0.6514
#   w4: 0.6709
#   w5: 0.0254
#   w6: 0.6320
#   w7: 0.4101
# Final Log-Likelihood : 197.50
# Final AIC            : -359.00
# ✓ Success: LL = 197.50
#
# ==================================================
# Fitting participant 26.0 (21/22)
# ==================================================
# Participant has 3592 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 1153.15
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1155.17  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 1172.34  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -2322.68  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1157.22  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 1175.31  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -2326.61  (vs current best: -2322.68)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1176.80  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1176.80  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -2325.60  (vs current best: -2326.61)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1181.78  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 1181.78  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 1181.78  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -2327.56  (vs current best: -2326.61)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 1186.53  [{'maxiter': 1100}]
#   Restart 4 (warm): LL = 1186.53  [{'maxiter': 1100}]
#   Restart 5 (random): LL = 1186.53  [{'tolx': 0.001}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -2321.07  (vs current best: -2327.56)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 5.3370
#   vPower: 0.5376
#   vBias: 0.5995
#   a: 1.1504
#   t0: 0.1955
#   w: 0.4525
#   weight_w: 0.0000
#   weight_v: 1.3713
#   lapse: 0.0247
#   bias_strength: 0.8561
#   w0: 0.2678
#   w1: 0.6613
#   w2: 0.3716
#   w3: 0.7745
#   w4: 0.4630
#   w5: 0.3982
#   w6: 0.4282
#   w7: 0.5496
# Final Log-Likelihood : 1181.78
# Final AIC            : -2327.56
# ✓ Success: LL = 1181.78
#
# ==================================================
# Fitting participant 27.0 (22/22)
# ==================================================
# Participant has 3590 trials
# Running optimization for k = [1, 2, 3, 4, 5]
# Running Stage 1 (DDM only)...
#   Stage 1 DDM fit: LL = 2629.87
#
# === Optimizing with fixed k = 1 (n_params=11) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2641.90  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 2641.91  [{'tolx': 0.001}]
#   Restart 5 (random): LL = 2643.42  [{'tolx': 0.001}]
#   Successful fits for k=1: 7/7
#   AIC for k=1: -5264.85  (vs current best: inf)
#
# === Optimizing with fixed k = 2 (n_params=12) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2650.62  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2650.62  [{'tolx': 0.001}]
#   Restart 4 (warm): LL = 2663.79  [{'tolx': 0.001}]
#   Successful fits for k=2: 7/7
#   AIC for k=2: -5303.57  (vs current best: -5264.85)
#
# === Optimizing with fixed k = 3 (n_params=14) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2629.86  [{'tolx': 0.001}]
#   Restart 2 (warm): LL = 2674.30  [{'tolx': 0.001}]
#   Restart 3 (warm): LL = 2674.30  [{'tolx': 0.001}]
#   Successful fits for k=3: 7/7
#   AIC for k=3: -5320.60  (vs current best: -5303.57)
#
# === Optimizing with fixed k = 4 (n_params=18) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2684.75  [{'tolx': 0.001}]
#   Restart 6 (warm): LL = 2684.75  [{'tolx': 0.001}]
#   Successful fits for k=4: 7/7
#   AIC for k=4: -5333.50  (vs current best: -5320.60)
#
# === Optimizing with fixed k = 5 (n_params=26) ===
#   Running Stage 2 (full fit)...
#   Restart 1 (random): LL = 2690.24  [{'maxiter': 1100}]
#   Successful fits for k=5: 7/7
#   AIC for k=5: -5328.49  (vs current best: -5333.50)
#
# === Best overall fit (by AIC) ===
# k = 4
#   vSlope: 4.7806
#   vPower: 0.2708
#   vBias: -0.3086
#   a: 1.0385
#   t0: 0.2170
#   w: 0.5203
#   weight_w: 0.0000
#   weight_v: 1.4460
#   lapse: 0.0162
#   bias_strength: 46.2346
#   w0: 0.0021
#   w1: 0.7052
#   w2: 0.4133
#   w3: 0.6458
#   w4: 0.5775
#   w5: 0.2052
#   w6: 0.5709
#   w7: 0.6887
# Final Log-Likelihood : 2684.75
# Final AIC            : -5333.50
# ✓ Success: LL = 2684.75
#
# Parameter summary (successful fits only):
#               id     vSlope     vPower      vBias          a         t0  \
# count  22.000000  22.000000  22.000000  22.000000  22.000000  22.000000
# mean   13.454545   4.643156   0.501643  -0.030092   1.324974   0.206404
# std     8.122440   1.117778   0.190271   0.599206   0.219537   0.118221
# min     1.000000   2.475855   0.270763  -1.062980   0.930750   0.007688
# 25%     6.250000   3.994538   0.312317  -0.249797   1.186850   0.141224
# 50%    13.500000   4.425116   0.527321  -0.113658   1.308740   0.210456
# 75%    19.750000   5.494892   0.625417   0.110675   1.445904   0.257291
# max    27.000000   6.224120   1.000000   1.308696   1.916337   0.438791
#
#                w   weight_w      weight_v         lapse  ...         w9  \
# count  22.000000  22.000000  2.200000e+01  2.200000e+01  ...  22.000000
# mean    0.508357   0.284575  8.838303e-01  2.035828e-02  ...  -0.670581
# std     0.035427   1.003166  6.947716e-01  1.190772e-02  ...   0.628388
# min     0.427459   0.000001  6.331915e-07  3.829067e-09  ...  -1.000000
# 25%     0.494949   0.000002  2.989294e-01  1.399614e-02  ...  -1.000000
# 50%     0.507632   0.000002  7.895362e-01  1.686024e-02  ...  -1.000000
# 75%     0.525736   0.148571  1.359606e+00  2.506108e-02  ...  -1.000000
# max     0.591783   4.732420  2.452868e+00  5.228473e-02  ...   0.802877
#
#              w10        w11        w12        w13        w14        w15  \
# count  22.000000  22.000000  22.000000  22.000000  22.000000  22.000000
# mean   -0.586685  -0.715868  -0.660833  -0.696013  -0.676542  -0.613841
# std     0.786162   0.544033   0.644364   0.577197   0.617471   0.736428
# min    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# 25%    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# 50%    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# 75%    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# max     0.998875   0.529578   0.697719   0.561380   0.622245   0.936892
#
#                k  max_log_lik          aic
# count  22.000000    22.000000    22.000000
# mean    3.272727   541.462219 -1048.833529
# std     1.386390  1192.125232  2379.862166
# min     1.000000 -3094.494713 -5427.561441
# 25%     2.000000   212.286911 -2097.974457
# 50%     3.500000   809.362769 -1580.725538
# 75%     4.000000  1068.154465  -388.573822
# max     5.000000  2739.780721  6212.989425
#
# [8 rows x 30 columns]
#
# Results saved to: SPRB.csv
#
# First few results:
#       id    vSlope    vPower     vBias         a        t0         w  \
# 0    1.0  4.291373  0.704013  1.272350  1.203980  0.007688  0.427459
# 1    2.0  4.447582  0.451554 -0.224478  1.103210  0.214002  0.540617
# 2    3.0  6.224120  0.638696 -0.784573  1.180402  0.261358  0.532421
# 3    4.0  4.068469  0.405905  0.090565  1.631311  0.148752  0.494916
# 4    5.0  6.147745  0.529857 -0.407292  0.930750  0.235732  0.560062
# 5    6.0  2.475855  0.524784 -0.092635  1.916337  0.386688  0.517437
# 6    7.0  3.969894  0.328428  0.645457  1.181140  0.310867  0.474737
# 7    9.0  3.694411  0.273359 -0.188365  1.326750  0.399193  0.539147
# 8   11.0  3.002060  0.271708 -0.024290  1.316289  0.324948  0.500291
# 9   12.0  5.047268  0.446289 -0.131786  1.469131  0.438791  0.508373
# 10  13.0  3.075003  0.298366 -0.258237  1.338780  0.140669  0.495048
# 11  14.0  4.402650  0.585581 -1.051008  1.258534  0.068778  0.591783
# 12  15.0  4.246001  0.306946 -0.164686  1.376222  0.123764  0.496492
# 13  16.0  6.153146  0.531770 -0.095530  1.222015  0.142889  0.504201
# 14  18.0  6.178357  0.745835  0.117379  1.503768  0.220639  0.522181
# 15  19.0  4.290897  0.544848 -0.015547  1.301191  0.245092  0.506891
# 16  20.0  5.526487  0.641086  0.277372  1.336087  0.206910  0.477072
# 17  21.0  5.874334  0.697315 -1.062980  1.233944  0.042306  0.526921
# 18  23.0  5.400105  1.000000  1.308696  1.560551  0.189533  0.477437
# 19  24.0  3.516066  0.301401 -0.163331  1.570097  0.019745  0.517564
# 20  26.0  5.336996  0.537636  0.599468  1.150435  0.195500  0.452522
# 21  27.0  4.780619  0.270763 -0.308579  1.038491  0.217039  0.520270
#
#     weight_w      weight_v         lapse  ...        w9       w10       w11  \
# 0   0.000015  2.764398e-01  3.829067e-09  ... -1.000000 -1.000000 -1.000000
# 1   0.000001  1.702117e+00  2.516738e-02  ... -1.000000 -1.000000 -1.000000
# 2   0.000002  7.852235e-01  4.112271e-02  ... -1.000000 -1.000000 -1.000000
# 3   0.000002  3.663980e-01  2.033279e-02  ... -1.000000 -1.000000 -1.000000
# 4   0.000005  2.452868e+00  2.287758e-02  ...  0.345951  0.997066  0.063324
# 5   0.532549  2.343840e-01  2.575390e-02  ... -1.000000 -1.000000 -1.000000
# 6   0.180866  6.331915e-07  2.335043e-02  ... -1.000000 -1.000000 -1.000000
# 7   0.315554  4.984402e-06  1.401224e-02  ... -1.000000 -1.000000 -1.000000
# 8   0.000002  1.108865e+00  1.133954e-02  ... -1.000000 -1.000000 -1.000000
# 9   0.000002  1.324463e+00  1.752705e-02  ...  0.258460  0.998875  0.131204
# 10  0.000002  9.843057e-01  1.341144e-02  ... -1.000000 -1.000000 -1.000000
# 11  0.051688  4.332066e-01  1.136232e-02  ... -1.000000 -1.000000 -1.000000
# 12  0.000002  1.150173e+00  2.725046e-02  ...  0.446441  0.673342  0.420355
# 13  0.000002  2.116138e+00  3.807503e-02  ...  0.393488  0.927207  0.106433
# 14  0.235996  4.709285e-01  5.228473e-02  ... -1.000000 -1.000000 -1.000000
# 15  0.211529  7.079240e-01  1.560479e-02  ... -1.000000 -1.000000 -1.000000
# 16  0.000001  1.485206e+00  1.462692e-02  ...  0.802877  0.496442  0.529578
# 17  0.000001  2.338141e-01  1.399077e-02  ... -1.000000 -1.000000 -1.000000
# 18  4.732420  6.259484e-04  1.460166e-02  ... -1.000000 -1.000000 -1.000000
# 19  0.000003  7.938490e-01  4.254837e-03  ... -1.000000 -1.000000 -1.000000
# 20  0.000001  1.371320e+00  2.474217e-02  ... -1.000000 -1.000000 -1.000000
# 21  0.000002  1.446013e+00  1.619343e-02  ... -1.000000 -1.000000 -1.000000
#
#          w12       w13       w14       w15  k  max_log_lik          aic
# 0  -1.000000 -1.000000 -1.000000 -1.000000  1   855.958999 -1689.917999
# 1  -1.000000 -1.000000 -1.000000 -1.000000  2  1050.006145 -2076.012291
# 2  -1.000000 -1.000000 -1.000000 -1.000000  2   800.245982 -1576.491964
# 3  -1.000000 -1.000000 -1.000000 -1.000000  3  -546.977291  1121.954581
# 4   0.637804  0.200193  0.435833  0.703020  5  2739.780721 -5427.561441
# 5  -1.000000 -1.000000 -1.000000 -1.000000  2 -3094.494713  6212.989425
# 6  -1.000000 -1.000000 -1.000000 -1.000000  3  1129.499691 -2230.999381
# 7  -1.000000 -1.000000 -1.000000 -1.000000  3   908.002277 -1788.004555
# 8  -1.000000 -1.000000 -1.000000 -1.000000  4   298.456149  -560.912298
# 9   0.446522  0.281857  0.590959  0.888914  5   828.108520 -1604.217040
# 10 -1.000000 -1.000000 -1.000000 -1.000000  4   256.645738  -477.291477
# 11 -1.000000 -1.000000 -1.000000 -1.000000  3   675.934461 -1323.868921
# 12  0.302571  0.561380  0.622245  0.639934  5   818.479556 -1584.959112
# 13  0.697719  0.245904  0.376402  0.326746  5  1078.647590 -2105.295179
# 14 -1.000000 -1.000000 -1.000000 -1.000000  1  -982.012799  1986.025598
# 15 -1.000000 -1.000000 -1.000000 -1.000000  4    86.657404  -137.314807
# 16  0.377064  0.398370  0.090644  0.936892  5   398.401960  -744.803920
# 17 -1.000000 -1.000000 -1.000000 -1.000000  2  1074.203904 -2124.407809
# 18 -1.000000 -1.000000 -1.000000 -1.000000  1  -527.402728  1076.805456
# 19 -1.000000 -1.000000 -1.000000 -1.000000  4   197.500635  -359.001271
# 20 -1.000000 -1.000000 -1.000000 -1.000000  4  1181.778569 -2327.557138
# 21 -1.000000 -1.000000 -1.000000 -1.000000  4  2684.748044 -5333.496088
#
# [22 rows x 30 columns]

# %%
df2 = pd.read_csv("SPRBLnoGamma.csv")
df3 = pd.read_csv("SPRB.csv")
df2["aic"] - df3["aic"]
# Out:
# 0     -11.870450
# 1     -48.373328
# 2       2.658159
# 3      -0.892467
# 4     -75.839364
# 5     -13.649726
# 6     -40.051398
# 7       2.124130
# 8     -15.991856
# 9     -57.062582
# 10    -24.954615
# 11    -32.125378
# 12    -41.850729
# 13    -10.279960
# 14    -26.034625
# 15    -24.661213
# 16   -145.134760
# 17    -76.275916
# 18   -293.382322
# 19     -0.180219
# 20    -93.691715
# 21    -27.085048
# Name: aic, dtype: float64

# %%
df = pd.read_csv("/Users/Anton/Desktop/BachelorProjekt/UraiData/ForFirstDraftVbias/PureDDM.csv")
round(df[list(df.columns[1:4]) + ["w","t0"]],2)
# Out:
#     vSlope  vPower  vBias     w    t0
# 0     4.32    0.71   1.30  0.43  0.01
# 1     4.73    0.45  -0.23  0.54  0.22
# 2     6.58    0.63  -0.78  0.53  0.26
# 3     4.42    0.38   0.08  0.50  0.15
# 4     6.40    0.52  -0.42  0.56  0.24
# 5     2.69    0.50  -0.10  0.52  0.38
# 6     4.06    0.33   0.65  0.48  0.31
# 7     3.75    0.27  -0.18  0.54  0.40
# 8     3.13    0.28  -0.02  0.50  0.33
# 9     5.28    0.43  -0.15  0.51  0.45
# 10    3.22    0.29  -0.27  0.49  0.15
# 11    4.43    0.59  -1.01  0.59  0.07
# 12    4.52    0.30  -0.18  0.49  0.13
# 13    7.26    0.50  -0.11  0.51  0.15
# 14    8.61    0.64   0.26  0.52  0.23
# 15    4.54    0.53  -0.02  0.51  0.25
# 16    6.36    0.60   0.35  0.48  0.21
# 17    6.37    0.69  -1.20  0.53  0.05
# 18    6.36    1.14   1.30  0.48  0.21
# 19    3.70    0.31  -0.16  0.52  0.03
# 20    5.52    0.53   0.67  0.45  0.20
# 21    5.06    0.26  -0.35  0.52  0.22

# %%
df2_par - round(df[list(df.columns[1:4]) + ["w"]],2)
# Out:
#     vSlope  vPower  vBias     w
# 0    -0.05   -0.01  -0.43  0.00
# 1    -0.29    0.00   0.10  0.00
# 2    -0.36    0.01   0.01  0.00
# 3    -0.34    0.03   0.00 -0.01
# 4    -0.22    0.01   0.12  0.00
# 5    -0.21    0.03   0.01  0.00
# 6    -0.11    0.00  -0.48  0.00
# 7    -0.06    0.00  -0.02  0.00
# 8    -0.12    0.00   0.03  0.00
# 9    -0.35    0.01   0.15  0.01
# 10   -0.14    0.02   0.19  0.01
# 11   -0.02   -0.01   0.14  0.01
# 12   -0.25    0.01   0.19  0.01
# 13   -1.10    0.04   0.06 -0.01
# 14   -2.41    0.11  -0.12 -0.01
# 15   -0.23    0.02  -0.01  0.00
# 16   -0.76    0.05  -0.23  0.00
# 17   -0.44    0.01   0.05  0.10
# 18   -0.75   -0.14  -0.05 -0.11
# 19   -0.17   -0.01   0.02  0.00
# 20   -0.16    0.01  -0.31  0.00
# 21   -0.35    0.01   0.10  0.00
